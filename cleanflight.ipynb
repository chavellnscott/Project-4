# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
flights_df = pd.read_csv('C:/Users/charl/Downloads/Atlanta_01_2023_Flights.csv')

# %%
Atl_dept = flights_df[flights_df['ORIGIN_CITY_NAME'] == 'Atlanta, GA']

# %%
Atl_dept
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK MKT_UNIQUE_CARRIER  \
# 2          1             1            7                 AA
# 4          1             1            7                 AA
# 5          1             1            7                 AA
# 7          1             1            7                 AA
# 8          1             1            7                 AA
# ...      ...           ...          ...                ...
# 56161      1            31            2                 WN
# 56162      1            31            2                 WN
# 56164      1            31            2                 WN
# 56166      1            31            2                 WN
# 56168      1            31            2                 WN
#
#        MKT_CARRIER_FL_NUM ORIGIN_CITY_NAME         DEST_CITY_NAME  \
# 2                    1051      Atlanta, GA  Dallas/Fort Worth, TX
# 4                    1151      Atlanta, GA              Miami, FL
# ...

# %%
AA_Atl_depts = Atl_dept[Atl_dept['MKT_UNIQUE_CARRIER'] == 'AA']

# %%
AA_Atl_depts
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK MKT_UNIQUE_CARRIER  \
# 2          1             1            7                 AA
# 4          1             1            7                 AA
# 5          1             1            7                 AA
# 7          1             1            7                 AA
# 8          1             1            7                 AA
# ...      ...           ...          ...                ...
# 54423      1            31            2                 AA
# 54429      1            31            2                 AA
# 54449      1            31            2                 AA
# 54451      1            31            2                 AA
# 54453      1            31            2                 AA
#
#        MKT_CARRIER_FL_NUM ORIGIN_CITY_NAME         DEST_CITY_NAME  \
# 2                    1051      Atlanta, GA  Dallas/Fort Worth, TX
# 4                    1151      Atlanta, GA              Miami, FL
# ...

# %%
AA_Atl_depts = AA_Atl_depts.fillna(0)

# %%
AA_Atl_depts
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK MKT_UNIQUE_CARRIER  \
# 2          1             1            7                 AA
# 4          1             1            7                 AA
# 5          1             1            7                 AA
# 7          1             1            7                 AA
# 8          1             1            7                 AA
# ...      ...           ...          ...                ...
# 54423      1            31            2                 AA
# 54429      1            31            2                 AA
# 54449      1            31            2                 AA
# 54451      1            31            2                 AA
# 54453      1            31            2                 AA
#
#        MKT_CARRIER_FL_NUM ORIGIN_CITY_NAME         DEST_CITY_NAME  \
# 2                    1051      Atlanta, GA  Dallas/Fort Worth, TX
# 4                    1151      Atlanta, GA              Miami, FL
# ...

# %%
AA_Atl_depts['Total_delay_minutes'] = AA_Atl_depts['DEP_DELAY_NEW'].where(AA_Atl_depts['DEP_DELAY_NEW'] != 0, 0).cumsum()

# %%
AA_Atl_depts['Total_deptartures'] = AA_Atl_depts.groupby((AA_Atl_depts['DAY_OF_MONTH'] == 0).cumsum()).cumcount() + 1

# %%
AA_Atl_depts['Total_delay_count'] = (AA_Atl_depts['DEP_DELAY_NEW'] != 0).cumsum()

# %%
AA_Atl_depts
# Out:
#        MONTH  DAY_OF_MONTH  DAY_OF_WEEK MKT_UNIQUE_CARRIER  \
# 2          1             1            7                 AA
# 4          1             1            7                 AA
# 5          1             1            7                 AA
# 7          1             1            7                 AA
# 8          1             1            7                 AA
# ...      ...           ...          ...                ...
# 54423      1            31            2                 AA
# 54429      1            31            2                 AA
# 54449      1            31            2                 AA
# 54451      1            31            2                 AA
# 54453      1            31            2                 AA
#
#        MKT_CARRIER_FL_NUM ORIGIN_CITY_NAME         DEST_CITY_NAME  \
# 2                    1051      Atlanta, GA  Dallas/Fort Worth, TX
# 4                    1151      Atlanta, GA              Miami, FL
# ...
